# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import scipy.stats as stats

# %%
data= pd.read_csv('speed_data_data.csv')

# %%
data
# Out:
#       gender   age   income  goal  \
# 0          0  21.0  69487.0   2.0
# 1          0  21.0  69487.0   2.0
# 2          0  21.0  69487.0   2.0
# 3          0  21.0  69487.0   2.0
# 4          0  21.0  69487.0   2.0
# ...      ...   ...      ...   ...
# 8373       1  25.0      NaN   1.0
# 8374       1  25.0      NaN   1.0
# 8375       1  25.0      NaN   1.0
# 8376       1  25.0      NaN   1.0
# 8377       1  25.0      NaN   1.0
#
#                                                  career  dec  attr  sinc  \
# 0                                                lawyer    1   6.0   9.0
# 1                                                lawyer    1   7.0   8.0
# 2                                                lawyer    1   5.0   8.0
# 3                                                lawyer    1   7.0   6.0
# 4                                                lawyer    1   5.0   6.0
# ...                                                 ...  ...   ...   ...
# ...

# %%
df=data

# %%
df.head()
# Out:
#    gender   age   income  goal  career  dec  attr  sinc  intel  fun  amb  \
# 0       0  21.0  69487.0   2.0  lawyer    1   6.0   9.0    7.0  7.0  6.0
# 1       0  21.0  69487.0   2.0  lawyer    1   7.0   8.0    7.0  8.0  5.0
# 2       0  21.0  69487.0   2.0  lawyer    1   5.0   8.0    9.0  8.0  5.0
# 3       0  21.0  69487.0   2.0  lawyer    1   7.0   6.0    8.0  7.0  6.0
# 4       0  21.0  69487.0   2.0  lawyer    1   5.0   6.0    7.0  7.0  6.0
#
#    shar  like  prob  met
# 0   5.0   7.0   6.0  2.0
# 1   6.0   7.0   5.0  1.0
# 2   7.0   7.0   NaN  1.0
# 3   8.0   7.0   6.0  2.0
# 4   6.0   6.0   6.0  2.0

# %%
df.isnull()
# Out:
#       gender    age  income   goal  career    dec   attr   sinc  intel    fun  \
# 0      False  False   False  False   False  False  False  False  False  False
# 1      False  False   False  False   False  False  False  False  False  False
# 2      False  False   False  False   False  False  False  False  False  False
# 3      False  False   False  False   False  False  False  False  False  False
# 4      False  False   False  False   False  False  False  False  False  False
# ...      ...    ...     ...    ...     ...    ...    ...    ...    ...    ...
# 8373   False  False    True  False   False  False  False  False  False  False
# 8374   False  False    True  False   False  False  False  False  False  False
# 8375   False  False    True  False   False  False  False  False  False  False
# 8376   False  False    True  False   False  False  False  False  False  False
# 8377   False  False    True  False   False  False  False  False  False  False
#
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       gender   age   income  goal   career  dec  attr  sinc  intel  fun  amb  \
# 0          0  21.0  69487.0   2.0   lawyer    1   6.0   9.0    7.0  7.0  6.0
# 1          0  21.0  69487.0   2.0   lawyer    1   7.0   8.0    7.0  8.0  5.0
# 3          0  21.0  69487.0   2.0   lawyer    1   7.0   6.0    8.0  7.0  6.0
# 4          0  21.0  69487.0   2.0   lawyer    1   5.0   6.0    7.0  7.0  6.0
# 5          0  21.0  69487.0   2.0   lawyer    0   4.0   9.0    7.0  4.0  6.0
# ...      ...   ...      ...   ...      ...  ...   ...   ...    ...  ...  ...
# 8351       1  27.0  55138.0   1.0  Banking    0   7.0   7.0    7.0  7.0  7.0
# 8352       1  27.0  55138.0   1.0  Banking    0   6.0   6.0    6.0  6.0  6.0
# 8353       1  27.0  55138.0   1.0  Banking    0   7.0   7.0    7.0  7.0  7.0
# 8354       1  27.0  55138.0   1.0  Banking    0   5.0  10.0   10.0  8.0  6.0
# 8355       1  27.0  55138.0   1.0  Banking    0   4.0   9.0    9.0  7.0  7.0
#
#       shar  like  prob  met
# ...

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', data=data)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=20,  color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
score_cols = ['attr', 'sinc', 'intel', 'fun',]
for i, col in enumerate(score_cols, 1):
    plt.subplot(2, 3, i)
    sns.histplot(data[col])
    plt.xlabel(col.capitalize())
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='dec', y='age', data=data)
plt.title('Age vs Decision')
plt.xlabel('Decision')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['income'],  color='green')
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 90))
sns.countplot(y='career', data=data, order=data['career'].value_counts().index)
plt.title('Career Distribution')
plt.xlabel('Count')
plt.ylabel('Career')
plt.show()

# %%
yes = data.loc[data.dec==1]
yes
# Out:
#       gender   age   income  goal   career  dec  attr  sinc  intel  fun  amb  \
# 0          0  21.0  69487.0   2.0   lawyer    1   6.0   9.0    7.0  7.0  6.0
# 1          0  21.0  69487.0   2.0   lawyer    1   7.0   8.0    7.0  8.0  5.0
# 3          0  21.0  69487.0   2.0   lawyer    1   7.0   6.0    8.0  7.0  6.0
# 4          0  21.0  69487.0   2.0   lawyer    1   5.0   6.0    7.0  7.0  6.0
# 6          0  21.0  69487.0   2.0   lawyer    1   7.0   6.0    7.0  4.0  6.0
# ...      ...   ...      ...   ...      ...  ...   ...   ...    ...  ...  ...
# 8340       1  27.0  55138.0   1.0  Banking    1   9.0   7.0    8.0  7.0  7.0
# 8341       1  27.0  55138.0   1.0  Banking    1   5.0   6.0    7.0  7.0  7.0
# 8343       1  27.0  55138.0   1.0  Banking    1   8.0   5.0    5.0  7.0  7.0
# 8346       1  27.0  55138.0   1.0  Banking    1   8.0   7.0    8.0  6.0  6.0
# 8347       1  27.0  55138.0   1.0  Banking    1   7.0   7.0    8.0  4.0  7.0
#
#       shar  like  prob  met
# ...

# %%
no = data.loc[data.dec==0]
no
# Out:
#       gender   age   income  goal   career  dec  attr  sinc  intel  fun  amb  \
# 5          0  21.0  69487.0   2.0   lawyer    0   4.0   9.0    7.0  4.0  6.0
# 10         0  24.0  65929.0   1.0      law    0   5.0   7.0    8.0  4.0  6.0
# 11         0  24.0  65929.0   1.0      law    0   8.0   5.0    6.0  6.0  9.0
# 12         0  24.0  65929.0   1.0      law    0   5.0   8.0    9.0  6.0  3.0
# 14         0  24.0  65929.0   1.0      law    0   6.0   8.0    7.0  9.0  7.0
# ...      ...   ...      ...   ...      ...  ...   ...   ...    ...  ...  ...
# 8351       1  27.0  55138.0   1.0  Banking    0   7.0   7.0    7.0  7.0  7.0
# 8352       1  27.0  55138.0   1.0  Banking    0   6.0   6.0    6.0  6.0  6.0
# 8353       1  27.0  55138.0   1.0  Banking    0   7.0   7.0    7.0  7.0  7.0
# 8354       1  27.0  55138.0   1.0  Banking    0   5.0  10.0   10.0  8.0  6.0
# 8355       1  27.0  55138.0   1.0  Banking    0   4.0   9.0    9.0  7.0  7.0
#
#       shar  like  prob  met
# ...

# %%
yes_dec= yes.income
yes_dec
# Out:
# 0       69487.0
# 1       69487.0
# 3       69487.0
# 4       69487.0
# 6       69487.0
#          ...
# 8340    55138.0
# 8341    55138.0
# 8343    55138.0
# 8346    55138.0
# 8347    55138.0
# Name: income, Length: 1417, dtype: float64

# %%
no_dec= no.income
no_dec
# Out:
# 5       69487.0
# 10      65929.0
# 11      65929.0
# 12      65929.0
# 14      65929.0
#          ...
# 8351    55138.0
# 8352    55138.0
# 8353    55138.0
# 8354    55138.0
# 8355    55138.0
# Name: income, Length: 2084, dtype: float64

# %%
yes.income.mean()
# Out:
# 46025.342272406495

# %%
no.income.mean()
# Out:
# 45062.03742802303

# %%
t_value, p_value = stats.ttest_ind(yes_dec, no_dec)
print("t_value : ",t_value,"\np_value : ", p_value)
alpha = 0.05
# Out:
# t_value :  1.6128334460211071
# p_value :  0.1068708778195684

# %%
if p_value<alpha:
    print("Reject the null hypothesis . the dating decision is based on high income")
else:
        print("fail to reject the null hypothesis. the dating decision is not based on high income")
# Out:
# fail to reject the null hypothesis. the dating decision is not based on high income

# %%
fun_less=no.fun
fun_less
# Out:
# 5       4.0
# 10      4.0
# 11      6.0
# 12      6.0
# 14      9.0
#        ...
# 8351    7.0
# 8352    6.0
# 8353    7.0
# 8354    8.0
# 8355    7.0
# Name: fun, Length: 2084, dtype: float64

# %%
fun_more=yes.fun
fun_more
# Out:
# 0       7.0
# 1       8.0
# 3       7.0
# 4       7.0
# 6       4.0
#        ...
# 8340    7.0
# 8341    7.0
# 8343    7.0
# 8346    6.0
# 8347    4.0
# Name: fun, Length: 1417, dtype: float64

# %%
t_value, p_value = stats.ttest_ind(fun_more, fun_less)
print("t_value : ",t_value,"\np_value : ", p_value)
alpha = 0.05
# Out:
# t_value :  27.88690339346592
# p_value :  1.0193002322758223e-154

# %%
if p_value<alpha:
    print("Reject the null hypothesis . the dating decision is based on funny character")
else:
        print("fail to reject the null hypothesis. the dating decision is not based on funny")
# Out:
# Reject the null hypothesis . the dating decision is based on funny character
